# %% [markdown]
# # Entendendo os dados

# %% [markdown]
# No ciclo 2 precisamos compreender melhor cada variável com o intuito de de fazer uma limpeza melhor e também uma melhor analise. Devemos procurar informações sobre o titanic fora do kaglle.

# %% [markdown]
# # Limpeza dos Dados

# %% [markdown]
# No ciclo 2 devemos seguir os seguintes passos para limpar os dados:
#
# - Vefirificar se os dados estão no formato certo.
# - Verificar se os dados possuem valores nan.
# - Verificar se os dados possuem outliers.
# - Verificar se os dados estão no tipo certo.

# %% [markdown]
# # Analise dos Dados
